# %% [markdown]
# # Churn Data Preprocessing

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler
from sklearn.compose import ColumnTransformer

# %% [markdown]
# ## Read the churn file

# %%
df=pd.read_csv("../data/churn.csv", sep=";")
df
# Out:
#       COLLEGE  INCOME  OVERAGE  LEFTOVER   HOUSE  HANDSET_PRICE  \
# 0        zero   31953        0         6  313378            161
# 1         one   36147        0        13  800586            244
# 2         one   27273      230         0  305049            201
# 3        zero  120070       38        33  788235            780
# 4         one   29215      208        85  224784            241
# ...       ...     ...      ...       ...     ...            ...
# 19995    zero  153252        0        23  368403            597
# 19996     one  107126       71        82  237397            609
# 19997    zero   78529        0        66  172589            275
# 19998    zero   78674       47        41  572406            288
# 19999    zero  124697        0         0  845575            808
#
#        OVER_15MINS_CALLS_PER_MONTH  AVERAGE_CALL_DURATION  \
# 0                                0                      4
# 1                                0                      6
# 2                               16                     15
# 3                                3                      2
# 4                               21                      1
# ...                            ...                    ...
# 19995                            1                      6
# 19996                            5                      2
# 19997                            0                      2
# 19998                            4                      2
# 19999                           24                     14
#
#       REPORTED_SATISFACTION REPORTED_USAGE_LEVEL CONSIDERING_CHANGE_OF_PLAN  \
# 0                     unsat               little                         no
# 1                     unsat               little                considering
# 2                     unsat          very_little                    perhaps
# 3                     unsat            very_high                considering
# 4                very_unsat               little              never_thought
# ...                     ...                  ...                        ...
# 19995              very_sat               little   actively_looking_into_it
# 19996              very_sat          very_little                         no
# 19997                 unsat            very_high                considering
# 19998            very_unsat               little                considering
# 19999                 unsat                 high   actively_looking_into_it
#
#        LEAVE
# 0       STAY
# 1       STAY
# 2       STAY
# 3      LEAVE
# 4       STAY
# ...      ...
# 19995   STAY
# 19996   STAY
# 19997  LEAVE
# 19998  LEAVE
# 19999  LEAVE
#
# [20000 rows x 12 columns]

# %% [markdown]
# ## Data Preparation
# ### Transform strings into numeric attributes

# %%
# TODO add LabelEncoder for the binary attributes
# TODO add OneHotEncoder for the nominal attributes 
# TODO add OrdinalEncoder for the ordinal attributes
