# %% [markdown]
# # Sales Data Cleaning

# %%
import pandas as pd

# %% [markdown]
# ## Read the input file

# %%
inputFile = pd.read_csv("../data/sales_for_data_cleaning.csv",delimiter=";")
display(inputFile)
# Out:
#               division  level of education  training level  work experience  \
# 0          peripherals        some college             1.0              6.0
# 1             printers         high school             3.0              7.0
# 2      office supplies  associate's degree             1.0              7.0
# 3      office supplies  associate's degree             0.0              9.0
# 4             printers  associate's degree             0.0              6.0
# ..                 ...                 ...             ...              ...
# 995           printers        some college             0.0              8.0
# 996    office supplies        some college             0.0              6.0
# 997  computer hardware  associate's degree             NaN              4.0
# 998           printers        some college             2.0              9.0
# 999  computer software  associate's degree             2.0              9.0
#
#      salary   sales
# 0     87067  299066
# ...

# %% [markdown]
# Lower devision

# %% [markdown]
# Filter lines with missing values

# %% [markdown]
# Fill missing values with avg
