# %% [markdown]
# # Sales Data Binning

# %%
import pandas as pd
from sklearn.preprocessing import KBinsDiscretizer

# %% [markdown]
# ## Read the input file

# %%
df = pd.read_csv("../data/sales_for_data_cleaning.csv",delimiter=";")
display(df)

# %% [markdown]
# Lower division

# %% [markdown]
# Filter lines with missing values

# %% [markdown]
# ### Binning of Salary

# %%
# TODO: Use pandas cut functionality to bin the "sales" column into 10 equal-width bins.

# %% [markdown]
# ### Discretize with scikit-learn

# %%
# TODO: Use KBinsDiscretizer from sklearn to bin the "sales" column into 10 equal-width and 10 equal-height bins.
