# %% [markdown]
# # Sales Data Transformation

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler
from sklearn.compose import ColumnTransformer

# %% [markdown]
# ## Read the input file

# %%
df = pd.read_csv("../data/sales.csv",delimiter=",")
display(df)

# %% [markdown]
# ## Encode Division (Label Encoder)

# %%
# TODO use LabelEncoder to encode the "division" column and add it as new column "division_le"

# %% [markdown]
# ## Encode Division (One Hot Encoder)

# %%
# TODO use OneHotEncoder to encode the "division" column

# %% [markdown]
# ## Encode Level of education (Ordinal Encoding)

# %%
# TODO use OridinalEncoder to encode the "level of education" column and add it as new column "edu_enc"

# %% [markdown]
# ### Z-Score

# %%
features = df[["training level", "work experience", "salary"]]
# TODO use StandardScaler to scale the features

# %% [markdown]
# ### Min Max

# %%
# TODO use Min Max Scaler to scale the features
